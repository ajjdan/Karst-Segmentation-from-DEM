# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
#tf.enable_eager_execution()

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

import numpy as np

import tensorflow.keras

import os
from glob import glob

import timeit

from matplotlib.backends.backend_pdf import PdfPages
from IPython.display import clear_output
import datetime

import pandas as pd

# %%
tf.reset_default_graph()

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
from Model import make_KaI

# %%
img_height = 1000
img_width = 1000
nclasses=2
filters=16
one_hot=2
deep = False
zero_pad = 0

KaI = make_KaI(img_height, img_width, nclasses, filters, one_hot, deep, zero_pad, channels = 1)
# Out:
# WARNING:tensorflow:From C:\Users\Veigel\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
import pydotplus
import keras.utils
keras.utils.vis_utils.pydot = pydotplus
tf.keras.utils.plot_model(KaI, to_file="D:/Masterarbeit/Data/model_full_KaI_slovenia.png", show_shapes=True)
# Out:
# Using TensorFlow backend.

# %%
from Data import image_generator

# %%
files_mask_train = glob("D:\\Masterarbeit\\Data\\high_res\\slovenia_1m\\tf_data\\train\\WOKAM\\subfolder\\*")
files_img_train = glob("D:\\Masterarbeit\\Data\\high_res\\slovenia_1m\\tf_data\\train\\LIDAR\\subfolder\\*")

files_mask_test = glob("D:\\Masterarbeit\\Data\\high_res\\slovenia_1m\\tf_data\\test\\WOKAM\\subfolder\\*")
files_img_test = glob("D:\\Masterarbeit\\Data\\high_res\\slovenia_1m\\tf_data\\test\\LIDAR\\subfolder\\*")

# %%
train_generator = image_generator(files_img_train, files_mask_train, batch_size = 2, intensify = False, random = True, categorical =True, lidar = True)
test_generator = image_generator(files_img_test, files_mask_test, batch_size = 2, intensify = False, random = False, categorical = True, lidar = True)

# %%
for i in range(0,1):
    
    x, y = next(train_generator)
    
    image = x[i].reshape(1000,1000)
    #mask = np.argmax(y[i], axis=2)
    mask = y[i].reshape(1000,1000)
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,10))
    ax1.imshow(image, cmap = "Greys")
    ax2.imshow(mask, cmap = "Greys")
    
    plt.show()

# %%
adam = tf.keras.optimizers.Adam(lr=0.001)

# %%
KaI.compile(optimizer= adam, loss = "categorical_crossentropy", metrics=['categorical_accuracy'])

# %%
batch_size = 2

# %%
tb_dir = "D:\\Masterarbeit\\Data\\logs\\fit\\" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")+ "_high_res_binary"

tb = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, write_graph=True, histogram_freq= 1)
mc = tf.keras.callbacks.ModelCheckpoint(mode='max', filepath='D:/Masterarbeit/Data/weights/top_weights_200511_high_res_binaryt.h5', monitor='binary_accuracy', save_best_only='True', save_weights_only='True', verbose=1)
callbacks = [tb, mc]

a = datetime.datetime.now()
history = KaI.fit_generator(
train_generator,
steps_per_epoch=len(files_mask_train) // batch_size,
epochs= 100,
validation_data= test_generator,
validation_steps=len(files_mask_test) // batch_size , 
callbacks=callbacks
)
b = datetime.datetime.now()
print(b-a)

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = 'D:/Masterarbeit/Data/weights/history_high_res_binary.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)
# Out:
# Epoch 1/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6941 - binary_accuracy: 0.5118Epoch 1/100
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-38-70b42afc6a28> in <module>
#      12 validation_data= test_generator,
#      13 validation_steps=len(files_mask_test) // batch_size ,
# ---> 14 callbacks=callbacks
#      15 )
#      16 b = datetime.datetime.now()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1294         shuffle=shuffle,
#    1295         initial_epoch=initial_epoch,
# -> 1296         steps_name='steps_per_epoch')
#    1297
#    1298   def evaluate_generator(self,
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     321           verbose=verbose,
#     322           mode=ModeKeys.TEST,
# --> 323           steps_name='validation_steps')
#     324
#     325       if not isinstance(val_results, list):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training.py in test_on_batch(self, x, y, sample_weight, reset_metrics)
#    1103       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1104       self._make_test_function()
# -> 1105       outputs = self.test_function(inputs)  # pylint: disable=not-callable
#    1106
#    1107     if reset_metrics:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'image_input' with dtype float and shape [?,1000,1000,1]
# 	 [[{{node image_input}}]]

# %%
tb_dir = "D:\\Masterarbeit\\Data\\logs\\fit\\" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")+ "_high_res_categorical"

tb = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, write_graph=True, histogram_freq= 1)
mc = tf.keras.callbacks.ModelCheckpoint(mode='max', filepath='D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5', monitor='categoricalc uracy', save_best_only='True', save_weights_only='True', verbose=1)
callbacks = [tb, mc]

a = datetime.datetime.now()
history = KaI.fit_generator(
train_generator,
steps_per_epoch=len(files_mask_train) // batch_size,
epochs= 100,
validation_data= test_generator,
validation_steps=len(files_mask_test) // batch_size , 
callbacks=callbacks
)
b = datetime.datetime.now()
print(b-a)

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = 'D:/Masterarbeit/Data/weights/history_high_res_categorical.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)
# Out:
# Epoch 1/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6632 - categorical_accuracy: 0.6436Epoch 1/100
# 20/86 [=====>........................] - ETA: 13:38 - loss: 0.6022 - categorical_accuracy: 0.8443
# Epoch 00001: categorical_accuracy improved from -inf to 0.64357, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1234s 14s/step - loss: 0.6632 - categorical_accuracy: 0.6436 - val_loss: 0.6022 - val_categorical_accuracy: 0.8443
# Epoch 2/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6235 - categorical_accuracy: 0.7213Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:03 - loss: 0.6116 - categorical_accuracy: 0.8118
# Epoch 00002: categorical_accuracy improved from 0.64357 to 0.72313, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1276s 15s/step - loss: 0.6229 - categorical_accuracy: 0.7231 - val_loss: 0.6116 - val_categorical_accuracy: 0.8118
# Epoch 3/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6212 - categorical_accuracy: 0.7132Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:29 - loss: 0.5118 - categorical_accuracy: 0.9695
# Epoch 00003: categorical_accuracy did not improve from 0.72313
# 86/86 [==============================] - 1289s 15s/step - loss: 0.6214 - categorical_accuracy: 0.7124 - val_loss: 0.5118 - val_categorical_accuracy: 0.9695
# Epoch 4/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6199 - categorical_accuracy: 0.7182Epoch 1/100
# 20/86 [=====>........................] - ETA: 13:26 - loss: 0.5873 - categorical_accuracy: 0.5808
# Epoch 00004: categorical_accuracy did not improve from 0.72313
# 86/86 [==============================] - 1262s 15s/step - loss: 0.6209 - categorical_accuracy: 0.7151 - val_loss: 0.5873 - val_categorical_accuracy: 0.5808
# Epoch 5/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6239 - categorical_accuracy: 0.6846Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:10 - loss: 0.4822 - categorical_accuracy: 0.9695- ETA: 16:19 - loss: 0.4820 - categorical_accurac
# Epoch 00005: categorical_accuracy did not improve from 0.72313
# 86/86 [==============================] - 1279s 15s/step - loss: 0.6238 - categorical_accuracy: 0.6850 - val_loss: 0.4822 - val_categorical_accuracy: 0.9695
# Epoch 6/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5925 - categorical_accuracy: 0.7331Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:20 - loss: 0.5244 - categorical_accuracy: 0.8040
# Epoch 00006: categorical_accuracy improved from 0.72313 to 0.73545, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1289s 15s/step - loss: 0.5914 - categorical_accuracy: 0.7355 - val_loss: 0.5244 - val_categorical_accuracy: 0.8040
# Epoch 7/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6113 - categorical_accuracy: 0.6884Epoch 1/100
# 20/86 [=====>........................] - ETA: 15:07 - loss: 0.5055 - categorical_accuracy: 0.7925
# Epoch 00007: categorical_accuracy did not improve from 0.73545
# 86/86 [==============================] - 1298s 15s/step - loss: 0.6097 - categorical_accuracy: 0.6913 - val_loss: 0.5055 - val_categorical_accuracy: 0.7925
# Epoch 8/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6301 - categorical_accuracy: 0.6699Epoch 1/100
# 20/86 [=====>........................] - ETA: 16:43 - loss: 0.4543 - categorical_accuracy: 0.9686
# Epoch 00008: categorical_accuracy did not improve from 0.73545
# 86/86 [==============================] - 1290s 15s/step - loss: 0.6288 - categorical_accuracy: 0.6718 - val_loss: 0.4543 - val_categorical_accuracy: 0.9686
# Epoch 9/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5801 - categorical_accuracy: 0.7244Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:34 - loss: 0.4913 - categorical_accuracy: 0.9490
# Epoch 00009: categorical_accuracy did not improve from 0.73545
# 86/86 [==============================] - 1186s 14s/step - loss: 0.5821 - categorical_accuracy: 0.7212 - val_loss: 0.4913 - val_categorical_accuracy: 0.9490
# Epoch 10/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5860 - categorical_accuracy: 0.7116Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:02 - loss: 0.5175 - categorical_accuracy: 0.7650
# Epoch 00010: categorical_accuracy did not improve from 0.73545
# 86/86 [==============================] - 1223s 14s/step - loss: 0.5843 - categorical_accuracy: 0.7148 - val_loss: 0.5175 - val_categorical_accuracy: 0.7650
# Epoch 11/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5709 - categorical_accuracy: 0.7235Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:47 - loss: 0.4318 - categorical_accuracy: 0.9380
# Epoch 00011: categorical_accuracy did not improve from 0.73545
# 86/86 [==============================] - 1198s 14s/step - loss: 0.5692 - categorical_accuracy: 0.7264 - val_loss: 0.4318 - val_categorical_accuracy: 0.9380
# Epoch 12/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5647 - categorical_accuracy: 0.7422Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:44 - loss: 0.4326 - categorical_accuracy: 0.9232
# Epoch 00012: categorical_accuracy improved from 0.73545 to 0.74259, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1192s 14s/step - loss: 0.5643 - categorical_accuracy: 0.7426 - val_loss: 0.4326 - val_categorical_accuracy: 0.9232
# Epoch 13/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5826 - categorical_accuracy: 0.6939Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:57 - loss: 0.5337 - categorical_accuracy: 0.6694
# Epoch 00013: categorical_accuracy did not improve from 0.74259
# 86/86 [==============================] - 1157s 13s/step - loss: 0.5822 - categorical_accuracy: 0.6950 - val_loss: 0.5337 - val_categorical_accuracy: 0.6694
# Epoch 14/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5856 - categorical_accuracy: 0.7177Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:48 - loss: 0.4048 - categorical_accuracy: 0.9061
# Epoch 00014: categorical_accuracy did not improve from 0.74259
# 86/86 [==============================] - 1152s 13s/step - loss: 0.5874 - categorical_accuracy: 0.7148 - val_loss: 0.4048 - val_categorical_accuracy: 0.9061
# Epoch 15/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5459 - categorical_accuracy: 0.7627Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:41 - loss: 0.4357 - categorical_accuracy: 0.8360
# Epoch 00015: categorical_accuracy improved from 0.74259 to 0.76520, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1147s 13s/step - loss: 0.5441 - categorical_accuracy: 0.7652 - val_loss: 0.4357 - val_categorical_accuracy: 0.8360
# Epoch 16/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5740 - categorical_accuracy: 0.7275Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:45 - loss: 0.4300 - categorical_accuracy: 0.9024
# Epoch 00016: categorical_accuracy did not improve from 0.76520
# 86/86 [==============================] - 1152s 13s/step - loss: 0.5738 - categorical_accuracy: 0.7274 - val_loss: 0.4300 - val_categorical_accuracy: 0.9024
# Epoch 17/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.6698 - categorical_accuracy: 0.6320Epoch 1/100
# 20/86 [=====>........................] - ETA: 12
100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5215 - categorical_accuracy: 0.7750Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:59 - loss: 0.3291 - categorical_accuracy: 0.9583
# Epoch 00055: categorical_accuracy did not improve from 0.80577
# 86/86 [==============================] - 1153s 13s/step - loss: 0.5194 - categorical_accuracy: 0.7779 - val_loss: 0.3291 - val_categorical_accuracy: 0.9583
# Epoch 56/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.4962 - categorical_accuracy: 0.8075Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:48 - loss: 0.3183 - categorical_accuracy: 0.9610
# Epoch 00056: categorical_accuracy improved from 0.80577 to 0.80988, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1152s 13s/step - loss: 0.4940 - categorical_accuracy: 0.8099 - val_loss: 0.3183 - val_categorical_accuracy: 0.9610
# Epoch 57/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.6117 - categorical_accuracy: 0.7061Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:54 - loss: 0.3249 - categorical_accuracy: 0.9677
# Epoch 00057: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1153s 13s/step - loss: 0.6098 - categorical_accuracy: 0.7083 - val_loss: 0.3249 - val_categorical_accuracy: 0.9677
# Epoch 58/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5338 - categorical_accuracy: 0.7734Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:45 - loss: 0.3270 - categorical_accuracy: 0.9639
# Epoch 00058: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1149s 13s/step - loss: 0.5339 - categorical_accuracy: 0.7732 - val_loss: 0.3270 - val_categorical_accuracy: 0.9639
# Epoch 59/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5153 - categorical_accuracy: 0.7750Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:43 - loss: 0.3156 - categorical_accuracy: 0.9669
# Epoch 00059: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1149s 13s/step - loss: 0.5169 - categorical_accuracy: 0.7735 - val_loss: 0.3156 - val_categorical_accuracy: 0.9669
# Epoch 60/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5656 - categorical_accuracy: 0.7434Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:52 - loss: 0.3343 - categorical_accuracy: 0.9612
# Epoch 00060: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1157s 13s/step - loss: 0.5632 - categorical_accuracy: 0.7461 - val_loss: 0.3343 - val_categorical_accuracy: 0.9612
# Epoch 61/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5973 - categorical_accuracy: 0.7185Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:49 - loss: 0.3292 - categorical_accuracy: 0.9677
# Epoch 00061: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1159s 13s/step - loss: 0.5961 - categorical_accuracy: 0.7198 - val_loss: 0.3292 - val_categorical_accuracy: 0.9677
# Epoch 62/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5672 - categorical_accuracy: 0.7416Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:49 - loss: 0.3216 - categorical_accuracy: 0.9695
# Epoch 00062: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1153s 13s/step - loss: 0.5638 - categorical_accuracy: 0.7454 - val_loss: 0.3216 - val_categorical_accuracy: 0.9695
# Epoch 63/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5334 - categorical_accuracy: 0.7796Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:55 - loss: 0.3269 - categorical_accuracy: 0.9599
# Epoch 00063: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1159s 13s/step - loss: 0.5304 - categorical_accuracy: 0.7829 - val_loss: 0.3269 - val_categorical_accuracy: 0.9599
# Epoch 64/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5622 - categorical_accuracy: 0.7477Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:52 - loss: 0.3219 - categorical_accuracy: 0.9582
# Epoch 00064: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1160s 13s/step - loss: 0.5598 - categorical_accuracy: 0.7503 - val_loss: 0.3219 - val_categorical_accuracy: 0.9582
# Epoch 65/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.6340 - categorical_accuracy: 0.6810Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:54 - loss: 0.3351 - categorical_accuracy: 0.9623
# Epoch 00065: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1160s 13s/step - loss: 0.6374 - categorical_accuracy: 0.6768 - val_loss: 0.3351 - val_categorical_accuracy: 0.9623
# Epoch 66/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5395 - categorical_accuracy: 0.7641Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:50 - loss: 0.3496 - categorical_accuracy: 0.9631
# Epoch 00066: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1155s 13s/step - loss: 0.5381 - categorical_accuracy: 0.7659 - val_loss: 0.3496 - val_categorical_accuracy: 0.9631
# Epoch 67/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.
100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5709 - categorical_accuracy: 0.7273Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:23 - loss: 0.3502 - categorical_accuracy: 0.9676
# Epoch 00079: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1283s 15s/step - loss: 0.5678 - categorical_accuracy: 0.7314 - val_loss: 0.3502 - val_categorical_accuracy: 0.9676
# Epoch 80/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5284 - categorical_accuracy: 0.7775Epoch 1/100
# 20/86 [=====>........................] - ETA: 14:27 - loss: 0.3369 - categorical_accuracy: 0.9610
# Epoch 00080: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1293s 15s/step - loss: 0.5255 - categorical_accuracy: 0.7805 - val_loss: 0.3369 - val_categorical_accuracy: 0.9610
# Epoch 81/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6149 - categorical_accuracy: 0.7008Epoch 1/100
# 20/86 [=====>........................] - ETA: 18:39 - loss: 0.3434 - categorical_accuracy: 0.9689
# Epoch 00081: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1365s 16s/step - loss: 0.6137 - categorical_accuracy: 0.7021 - val_loss: 0.3434 - val_categorical_accuracy: 0.9689
# Epoch 82/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5785 - categorical_accuracy: 0.7380Epoch 1/100
# 20/86 [=====>........................] - ETA: 13:30 - loss: 0.3245 - categorical_accuracy: 0.9641
# Epoch 00082: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1211s 14s/step - loss: 0.5811 - categorical_accuracy: 0.7343 - val_loss: 0.3245 - val_categorical_accuracy: 0.9641
# Epoch 83/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5446 - categorical_accuracy: 0.7563Epoch 1/100
# 20/86 [=====>........................] - ETA: 19:55 - loss: 0.3449 - categorical_accuracy: 0.9605
# Epoch 00083: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1343s 16s/step - loss: 0.5469 - categorical_accuracy: 0.7537 - val_loss: 0.3449 - val_categorical_accuracy: 0.9605
# Epoch 84/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5815 - categorical_accuracy: 0.7279Epoch 1/100
# 20/86 [=====>........................] - ETA: 13:05 - loss: 0.3469 - categorical_accuracy: 0.9626
# Epoch 00084: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1201s 14s/step - loss: 0.5787 - categorical_accuracy: 0.7313 - val_loss: 0.3469 - val_categorical_accuracy: 0.9626
# Epoch 85/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.6189 - categorical_accuracy: 0.7017Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:11 - loss: 0.3495 - categorical_accuracy: 0.9621
# Epoch 00085: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1180s 14s/step - loss: 0.6181 - categorical_accuracy: 0.7023 - val_loss: 0.3495 - val_categorical_accuracy: 0.9621
# Epoch 86/100
# 85/86 [============================>.] - ETA: 11s - loss: 0.5512 - categorical_accuracy: 0.7555Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:00 - loss: 0.3756 - categorical_accuracy: 0.9561
# Epoch 00086: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1172s 14s/step - loss: 0.5546 - categorical_accuracy: 0.7513 - val_loss: 0.3756 - val_categorical_accuracy: 0.9561
# Epoch 87/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5462 - categorical_accuracy: 0.7590Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:45 - loss: 0.3429 - categorical_accuracy: 0.9625
# Epoch 00087: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1156s 13s/step - loss: 0.5451 - categorical_accuracy: 0.7605 - val_loss: 0.3429 - val_categorical_accuracy: 0.9625
# Epoch 88/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.4913 - categorical_accuracy: 0.8091Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:44 - loss: 0.3468 - categorical_accuracy: 0.9650
# Epoch 00088: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1152s 13s/step - loss: 0.4927 - categorical_accuracy: 0.8074 - val_loss: 0.3468 - val_categorical_accuracy: 0.9650
# Epoch 89/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5537 - categorical_accuracy: 0.7570Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:59 - loss: 0.3495 - categorical_accuracy: 0.9630
# Epoch 00089: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1156s 13s/step - loss: 0.5530 - categorical_accuracy: 0.7581 - val_loss: 0.3495 - val_categorical_accuracy: 0.9630
# Epoch 90/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5395 - categorical_accuracy: 0.7655Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:13 - loss: 0.3556 - categorical_accuracy: 0.9579
# Epoch 00090: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1161s 13s/step - loss: 0.5389 - categorical_accuracy: 0.7663 - val_loss: 0.3556 - val_categorical_accuracy: 0.9579
# Epoch 91/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5440 - categorical_accuracy: 0.7626Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:55 - loss: 0.3455 - categorical_accuracy: 0.9550
# Epoch 00091: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1153s 13s/step - loss: 0.5432 - categorical_accuracy: 0.7636 - val_loss: 0.3455 - val_categorical_accuracy: 0.9550
# Epoch 92/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5011 - categorical_accuracy: 0.7925Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:51 - loss: 0.2954 - categorical_accuracy: 0.9536
# Epoch 00092: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1154s 13s/step - loss: 0.5025 - categorical_accuracy: 0.7913 - val_loss: 0.2954 - val_categorical_accuracy: 0.9536
# Epoch 93/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.4940 - categorical_accuracy: 0.7990Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:03 - loss: 0.3156 - categorical_accuracy: 0.9566
# Epoch 00093: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1158s 13s/step - loss: 0.4927 - categorical_accuracy: 0.8004 - val_loss: 0.3156 - val_categorical_accuracy: 0.9566
# Epoch 94/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5150 - categorical_accuracy: 0.7821Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:53 - loss: 0.3133 - categorical_accuracy: 0.9587
# Epoch 00094: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1154s 13s/step - loss: 0.5158 - categorical_accuracy: 0.7812 - val_loss: 0.3133 - val_categorical_accuracy: 0.9587
# Epoch 95/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5718 - categorical_accuracy: 0.7392Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:47 - loss: 0.3025 - categorical_accuracy: 0.9656
# Epoch 00095: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1150s 13s/step - loss: 0.5730 - categorical_accuracy: 0.7377 - val_loss: 0.3025 - val_categorical_accuracy: 0.9656
# Epoch 96/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5729 - categorical_accuracy: 0.7308Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:43 - loss: 0.3082 - categorical_accuracy: 0.9695
# Epoch 00096: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1149s 13s/step - loss: 0.5742 - categorical_accuracy: 0.7296 - val_loss: 0.3082 - val_categorical_accuracy: 0.9695
# Epoch 97/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5721 - categorical_accuracy: 0.7296Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:53 - loss: 0.3225 - categorical_accuracy: 0.9690
# Epoch 00097: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1152s 13s/step - loss: 0.5747 - categorical_accuracy: 0.7271 - val_loss: 0.3225 - val_categorical_accuracy: 0.9690
# Epoch 98/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.4968 - categorical_accuracy: 0.7847Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:47 - loss: 0.3079 - categorical_accuracy: 0.9695
# Epoch 00098: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1152s 13s/step - loss: 0.5004 - categorical_accuracy: 0.7812 - val_loss: 0.3079 - val_categorical_accuracy: 0.9695
# Epoch 99/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.5506 - categorical_accuracy: 0.7463Epoch 1/100
# 20/86 [=====>........................] - ETA: 11:36 - loss: 0.3131 - categorical_accuracy: 0.9695
# Epoch 00099: categorical_accuracy did not improve from 0.80988
# 86/86 [==============================] - 1146s 13s/step - loss: 0.5505 - categorical_accuracy: 0.7465 - val_loss: 0.3131 - val_categorical_accuracy: 0.9695
# Epoch 100/100
# 85/86 [============================>.] - ETA: 10s - loss: 0.4754 - categorical_accuracy: 0.8148Epoch 1/100
# 20/86 [=====>........................] - ETA: 12:19 - loss: 0.3313 - categorical_accuracy: 0.9599
# Epoch 00100: categorical_accuracy improved from 0.80988 to 0.81693, saving model to D:/Masterarbeit/Data/weights/top_weights_200511_high_categorical.h5
# 86/86 [==============================] - 1165s 14s/step - loss: 0.4738 - categorical_accuracy: 0.8169 - val_loss: 0.3313 - val_categorical_accuracy: 0.9599
# 1 day, 8:44:30.886227
